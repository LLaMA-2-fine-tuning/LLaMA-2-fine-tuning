# %% [markdown]
# ### Google Drive 연동

# %%
# 구글 드라이브 연동
from getpass import getpass
import os

from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# LLaMA2 프로젝트를 직접 생성하시고 프로젝트 폴더로 들어갑시다.
# [왼쪽 메뉴에 폴더 모양 클릭] -> [drive] -> [Mydrive 에 오른쪽 마우스] -> [폴더 생성] -> [폴더 이름 LLaMA2]
# %cd /content/drive/MyDrive/LLaMA2
# Out:
# /content/drive/MyDrive/LLaMA2

# %% [markdown]
# ### 개인 엑세스 토큰 받기
#
# 맨 아래 첨부된 링크를 들어가시면 보다 자세히 설명되있습니다.
#
# 각자 만든 토큰을 복사 및 저장 해두고 다음 명령어를 실행하여 붙여넣기해봅시다.

# %%
# 개인 액세스 토큰 받기
github_token = getpass('Enter your GitHub Personal Access Token: ')
os.environ['GITHUB_AUTH'] = github_token
# Out:
# Enter your GitHub Personal Access Token: ··········

# %% [markdown]
# ### 깃허브 레포지토리 clone 해서 자신의 구글 드라이브에 다운로드 받기
# 해당 토큰을 사용하여 인증하셨다면
# 클론은 처음 한번만 진행하시고 그 이후로는 하지 않으셔도 됩니다.

# %%
# GitHub 레포지토리 Clone (처음 한번만 진행)
# !git clone https://$GITHUB_AUTH@github.com/LLaMA-2-fine-tuning/llama2-project.git
# Out:
# Cloning into 'llama2-project'...
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 9 (delta 2), reused 4 (delta 0), pack-reused 0
# Receiving objects: 100% (9/9), done.
# Resolving deltas: 100% (2/2), done.

# %%
# git 관련 정보 적기
# !git config --global user.email 'm1nddoong0321@korea.ac.kr'
# !git config --global user.name 'm1nddoong'

# %%
# 생성된 깃헙 폴더로 들어가기
# %cd /content/drive/MyDrive/LLaMA2/llama2-project
# Out:
# /content/drive/MyDrive/LLaMA2/llama2-project

# %% [markdown]
# ### 자신의 브랜치 만들기
# 아래 주석을 제거하고 진행하시면 됩니다.

# %%
# 자신의 브랜치 만들기
# !git branch m1nddoong

# 생성한 브랜치로 체크아웃
# !git checkout m1nddoong
# Out:
# Switched to branch 'm1nddoong'

# %% [markdown]
# ### llama2-code.ipynb 파일 수정하기
# 저희가 실질적으로 코딩을 할 파일은 llama2-code.ipynb 파일입니다. 각자 브랜치에서 이 파일을 수정해나가시면 되겠습니다.
#
# 그리고 현재 이 llama2-code-for-commit.ipynb 파일은 커밋을 위한 파일이므로 커밋을 할떄 열어서 위 자신의 브랜치 체크아웃 부분부터 진행하시면 됩니다.

# %%
# 수정 전 본인의 브랜치에서 수행하십셔!
# !git checkout [자신의 브랜치 이름]

# %% [markdown]
# ### 자신의 브랜치에 commit 하고 push 하기

# %%
# 수정 사항들 add
# !git add .
# !git status
# Out:
# On branch m1nddoong
# nothing to commit, working tree clean

# %%
# 커밋 메세지 보내기
# !git commit -m 'clone 받기'
# Out:
# On branch m1nddoong
# nothing to commit, working tree clean

# %%
# 본인 브랜치에 push
# !git push -u origin m1nddoong
# Out:
# Branch 'm1nddoong' set up to track remote branch 'm1nddoong' from 'origin'.
# Everything up-to-date

# %% [markdown]
# 각자 혹은 같이 코드를 작성한 후 코드를 공유하는 시간에 코드 리뷰를 통해서
#
# Pull request 와 Merge 를 진행하겠습니다!
#
# 지피티 프로젝트 화이팅 👏👏👏👏
#
# 출처 : https://velog.io/@shong676/Colab%EA%B3%BC-GitHub-%EC%97%B0%EB%8F%99%ED%95%98%EA%B8%B0
# https://gksdudrb922.tistory.com/208
#
# <br>
#
# ![image.png](data:image/png;base64,...)
