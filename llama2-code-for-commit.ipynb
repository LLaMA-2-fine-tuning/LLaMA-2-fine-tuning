# %% [markdown]
# # Google Drive 저장

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/LLaMA2
# Out:
# /content/drive/MyDrive/LLaMA2

# %% [markdown]
# # Colab과 GitHub 연동하기
#
# 출처 : https://velog.io/@shong676/Colab%EA%B3%BC-GitHub-%EC%97%B0%EB%8F%99%ED%95%98%EA%B8%B0

# %%
from getpass import getpass
import os

# 토큰 : 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

# GitHub Personal Access Token 입력
github_token = getpass('Enter your GitHub Personal Access Token: ')

# GitHub 리포지토리 클론
os.environ['GITHUB_AUTH'] = github_token
# !git clone https://$GITHUB_AUTH@github.com/LLaMA-2-fine-tuning/llama2-project.git
# Out:
# Enter your GitHub Personal Access Token: ··········
# Cloning into 'llama2-project'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (3/3), done.

# %%
# 생성된 깃헙 폴더로 들어가기
# %cd /content/drive/MyDrive/LLaMA2/llama2-project
# Out:
# /content/drive/MyDrive/LLaMA2/llama2-project

# %%
# git 관련 정보 적기
# !git config --global user.email 'm1nddoong0321@korea.ac.kr'
# !git config --global user.name 'm1nddoong'

# %%
# 파일 add 하기
# !git add Test_code.ipynb
# 직접 구글 드라이브에서 colab 파일 생성해도 된다.

# %%
# 변경된 파일 확인
# !git status
# !git add .
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	llama2-code.ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# main 으로 commit 하기
# !git commit -m 'Github Oraganization Connection Test'
# !git push origin main

# 이후에 commit 을 할때에는 브랜치를 생성해서 브랜치로 커밋합시다
# ex) !git push origin 본인브랜치
# Out:
# [main 304cfd3] Github Oraganization Connection Test
#  1 file changed, 1 insertion(+)
#  create mode 100644 llama2-code.ipynb
# Enumerating objects: 4, done.
# Counting objects: 100% (4/4), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 756 bytes | 151.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/LLaMA-2-fine-tuning/llama2-project.git
#    a757be0..304cfd3  main -> main
